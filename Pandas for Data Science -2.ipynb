# %% [markdown]
# # Pandas for Data Science -2

# %%
import pandas as pd

# %%
daily_tasks = {'Day':['Mon','Tue','Wed','Thur','Fri','Sat','Sun'],'Sleeping':[10,8,11,6,5,8,10],'excersice':[30,60,45,50,30,0,90],'working':[4,3,5,6,2,0,1]}

# %%
print(daily_tasks)
# Out:
# {'Day': ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun'], 'Sleeping': [10, 8, 11, 6, 5, 8, 10], 'excersice': [30, 60, 45, 50, 30, 0, 90], 'working': [4, 3, 5, 6, 2, 0, 1]}

# %%
df = pd.DataFrame(daily_tasks)

# %%
df
# Out:
#     Day  Sleeping  excersice  working
# 0   Mon        10         30        4
# 1   Tue         8         60        3
# 2   Wed        11         45        5
# 3  Thur         6         50        6
# 4   Fri         5         30        2
# 5   Sat         8          0        0
# 6   Sun        10         90        1

# %%
df.shape
# Out:
# (7, 4)

# %%
df.set_index(df['Day'],inplace=True) # inplace: object returned from set_index will return to the orignal df

# %%
df.shape
# Out:
# (7, 4)

# %%
df
# Out:
#        Day  Sleeping  excersice  working
# Day
# Mon    Mon        10         30        4
# Tue    Tue         8         60        3
# Wed    Wed        11         45        5
# Thur  Thur         6         50        6
# Fri    Fri         5         30        2
# Sat    Sat         8          0        0
# Sun    Sun        10         90        1

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('seaborn-poster')

# %%
df['working'].plot()
plt.show()

# %%
df.plot()
plt.show()
