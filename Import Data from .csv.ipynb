# %% [markdown]
# ## Import Data from CSV - readCSV Method

# %%
import pandas as pd

# %%
priceSeries = pd.read_csv('/Users/Akshay/Documents/Price.csv',squeeze=True)

# %%
priceSeries
# Out:
#      Price
# 0     1200
# 1     1200
# 2     1200
# 3     1200
# 4     3600
# 5     1200
# 6     1200
# 7     1200
# 8     1200
# 9     1200
# 10    1200
# 11    1200
# 12    1200
# 13    1200
# 14    1200
# 15    1200
# 16    1200
# 17    1200
# 18    3600
# 19    1200
# 20    1200
# 21    1200
# 22    1200
# 23    1200
# 24    1200
# 25    1200
# 26    1200
# 27    1200
# 28    1200
# 29    1200
# ..     ...
# 968   3600
# 969   1200
# 970   1200
# 971   1200
# 972   1200
# 973   1200
# 974   1200
# 975   1200
# 976   1200
# 977   1200
# 978   1200
# 979   1200
# 980   1200
# 981   1200
# 982   1200
# 983   1200
# 984   1200
# 985   1200
# 986   1200
# 987   3600
# 988   3600
# 989   1200
# 990   1200
# 991   1200
# 992   3600
# 993   1200
# 994   3600
# 995   7500
# 996   1200
# 997   1200
#
# [998 rows x 1 columns]

# %%
type(priceSeries)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## head() and tail() method for Series

# %%
priceSeries.head(10)
# Out:
# 0    1200
# 1    1200
# 2    1200
# 3    1200
# 4    3600
# 5    1200
# 6    1200
# 7    1200
# 8    1200
# 9    1200
# Name: Price, dtype: int64

# %%
priceSeries.tail()
# Out:
# 993    1200
# 994    3600
# 995    7500
# 996    1200
# 997    1200
# Name: Price, dtype: int64

# %% [markdown]
# ## More operation on Series with python built in functions

# %%
type(priceSeries)
# Out:
# pandas.core.series.Series

# %%
len(priceSeries)
# Out:
# 998

# %%
sorted(priceSeries)
# Out:
# [13,
#  250,
#  800,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
# ...

# %%
dir(priceSeries)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
# ...

# %%
max(priceSeries)
# Out:
# 7500

# %%
min(priceSeries)
# Out:
# 13

# %%
list(priceSeries)
# Out:
# [1200,
#  1200,
#  1200,
#  1200,
#  3600,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  3600,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  3600,
#  1200,
#  1200,
#  3600,
#  3600,
#  1200,
#  1200,
#  3600,
#  1200,
#  3600,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  3600,
#  1200,
#  1200,
#  1200,
#  1200,
#  3600,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  3600,
#  3600,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
#  1200,
# ...

# %%
dict(priceSeries)
# Out:
# {0: 1200,
#  1: 1200,
#  2: 1200,
#  3: 1200,
#  4: 3600,
#  5: 1200,
#  6: 1200,
#  7: 1200,
#  8: 1200,
#  9: 1200,
#  10: 1200,
#  11: 1200,
#  12: 1200,
#  13: 1200,
#  14: 1200,
#  15: 1200,
#  16: 1200,
#  17: 1200,
#  18: 3600,
#  19: 1200,
#  20: 1200,
#  21: 1200,
#  22: 1200,
#  23: 1200,
#  24: 1200,
#  25: 1200,
#  26: 1200,
#  27: 1200,
#  28: 1200,
#  29: 1200,
#  30: 1200,
#  31: 1200,
#  32: 1200,
#  33: 1200,
#  34: 1200,
#  35: 1200,
#  36: 3600,
#  37: 1200,
#  38: 1200,
#  39: 3600,
#  40: 3600,
#  41: 1200,
#  42: 1200,
#  43: 3600,
#  44: 1200,
#  45: 3600,
#  46: 1200,
#  47: 1200,
#  48: 1200,
#  49: 1200,
#  50: 1200,
#  51: 1200,
#  52: 1200,
#  53: 1200,
#  54: 1200,
#  55: 1200,
#  56: 1200,
#  57: 1200,
#  58: 1200,
#  59: 3600,
#  60: 1200,
#  61: 1200,
#  62: 1200,
#  63: 1200,
#  64: 3600,
#  65: 1200,
#  66: 1200,
#  67: 1200,
#  68: 1200,
#  69: 1200,
#  70: 1200,
#  71: 1200,
#  72: 1200,
#  73: 1200,
#  74: 1200,
#  75: 1200,
#  76: 1200,
# ...

# %% [markdown]
# ## .sort_value() and .sort_indexes() methods

# %%
priceSeries.head(5)
# Out:
# 0    1200
# 1    1200
# 2    1200
# 3    1200
# 4    3600
# Name: Price, dtype: int64

# %%
priceSeries.sort_values().head()
# Out:
# 558      13
# 477     250
# 294     800
# 0      1200
# 628    1200
# Name: Price, dtype: int64

# %%
priceSeries.sort_values(ascending=False).tail()
# Out:
# 628    1200
# 0      1200
# 294     800
# 477     250
# 558      13
# Name: Price, dtype: int64

# %%
priceSeries.sort_index().tail()
# Out:
# 993    1200
# 994    3600
# 995    7500
# 996    1200
# 997    1200
# Name: Price, dtype: int64

# %%
priceSeries[993]
# Out:
# 1200
